# %%
import socket

# %%
url = input('Enter URL:')
ip_address = socket.gethostbyname(url)

print(f'[INFO] IP address of {url} is: {ip_address}')
# Out:
# Enter URL:www.yandex.ru
# [INFO] IP address of www.yandex.ru is: 5.255.255.50
